# %% [markdown]
# # 01 — fMRI Exploration for PTSD Classification
#
# **Purpose:** Demonstrate Nilearn fMRI loading, atlas parcellation, and
# resting-state connectivity matrix computation for PTSD vs control.
#
# **Requires:** ENIGMA data access or OpenNeuro fear conditioning dataset.

# %%
import sys
sys.path.insert(0, '../..')

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# Nilearn for fMRI
from nilearn import datasets, plotting, connectome
from classifiers.trauma.data import TraumaConfig, load_fmri_connectivity
from classifiers.trauma.features import extract_connectivity_features

# %% [markdown]
# ## 1. Load Atlas and Visualize Brain Parcellation

# %%
# Fetch Schaefer atlas (100 ROIs)
atlas = datasets.fetch_atlas_schaefer_2018(n_rois=100)
print(f'Atlas: {len(atlas.labels)} regions')
print(f'First 10 labels: {atlas.labels[:10]}')

# Plot the atlas on a brain
plotting.plot_roi(atlas.maps, title='Schaefer 100 Atlas',
                  display_mode='ortho', colorbar=True)
plt.show()

# %% [markdown]
# ## 2. Load fMRI Data and Compute Connectivity
#
# Replace `fmri_dir` with your actual fMRIPrep output path.

# %%
# fmri_dir = Path('../../data/raw/enigma/derivatives/fmriprep')
# config = TraumaConfig(fmri_dir=fmri_dir)
# dataset = load_fmri_connectivity(fmri_dir, config)
# features = extract_connectivity_features(dataset.connectivity_matrices)
# print(f'Subjects: {len(dataset.subjects)}')
# print(f'Feature shape: {features.shape}')
print('Uncomment above when ENIGMA data is available')
